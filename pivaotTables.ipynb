# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # pivot tables

# %%
import pandas as pd
import numpy as np

data = {
    'Date': pd.date_range('2023-01-01', periods=20),

    'Product': ['A', 'B', 'C', 'D'] * 5,

    'Region': [
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South'
    ],

    'Sales': np.random.randint(100, 1000, 20),

    'Units': np.random.randint(10, 100, 20),

    'Rep': [
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice'
    ]
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()

df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)



df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    556     82   John  January      Q1
# 1  2023-01-02       B   West    645     65   Mary  January      Q1
# 2  2023-01-03       C  North    282     56    Bob  January      Q1
# 3  2023-01-04       D  South    269     69  Alice  January      Q1
# 4  2023-01-05       A   East    362     12   John  January      Q1
# 5  2023-01-06       B   West    819     19   Mary  January      Q1
# 6  2023-01-07       C  North    464     15    Bob  January      Q1
# 7  2023-01-08       D  South    538     67  Alice  January      Q1
# 8  2023-01-09       A   East    999     25   John  January      Q1
# 9  2023-01-10       B   West    793     85   Mary  January      Q1
# 10 2023-01-11       C  North    679     96    Bob  January      Q1
# 11 2023-01-12       D  South    344     13  Alice  January      Q1
# 12 2023-01-13       A   East    107     22   John  January      Q1
# 13 2023-01-14       B   West    341     62   Mary  January      Q1
# 14 2023-01-15       C  North    303     12    Bob  January      Q1
# 15 2023-01-16       D  South    957     73  Alice  January      Q1
# 16 2023-01-17       A   East    664     24   John  January      Q1
# 17 2023-01-18       B   West    596     20   Mary  January      Q1
# 18 2023-01-19       C  North    983     69    Bob  January      Q1
# 19 2023-01-20       D  South    927     54  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales", index = 'Region', columns='Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     556.0    NaN    NaN    NaN
# North      NaN    NaN  464.0    NaN
# South      NaN    NaN    NaN  538.0
# West       NaN  645.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=['Sales','Units'], index = 'Region', columns='Product', aggfunc='median')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     556.0    NaN    NaN    NaN  24.0   NaN   NaN   NaN
# North      NaN    NaN  464.0    NaN   NaN   NaN  56.0   NaN
# South      NaN    NaN    NaN  538.0   NaN   NaN   NaN  67.0
# West       NaN  645.0    NaN    NaN   NaN  62.0   NaN   NaN

# %% [markdown]
# # croos tables

# %%
pd.crosstab('Region',df['Product'])
# Out:
# Product  A  B  C  D
# row_0
# Region   5  5  5  5
